# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.linspace(0, 10, 11)

y = x ** 2

# %%
plt.plot(x, y)

# %%
# plt.subplot(nrows, ncolumns, number_of_plot)

plt.subplot(2,2,1)
plt.plot(x, y)

plt.subplot(2,2,2)
plt.plot(x, x **3)

plt.subplot(2,2,3)
plt.plot(x, x)

plt.subplot(2,2,4)
plt.plot(x, x/2)

# %%
# Out:
# Text(0, 0.5, 'Money')
