# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from termcolor import colored

# %%
The World Happiness Index 2015 was conducted on 158 countries and contained only 12 different features.
The World Happiness Index 2016 was conducted on 157 countries and contained only 13 different features.
The World Happiness Index 2017 was conducted on 155 countries and contained only 12 different features.

# %%
shape = pd.DataFrame({"Total Rows": [
                                     df_2017.shape[0], 
                                     df_2016.shape[0], 
                                     df_2015.shape[0]],
                      "Total Columns": [
                                        df_2017.shape[1],
                                        df_2016.shape[1],
                                        df_2015.shape[1]]
                     },index=["df_2017", "df_2016","df_2015"]
                    )
shape
# Out:
#          Total Rows  Total Columns
# df_2017         155             12
# df_2016         157             13
# df_2015         158             12

# %%
df_all = [df_2017, df_2016, df_2015]
years = [2017,2016,2015]

# %%
plt.suptitle("Correlation of World Happiness Index [2015-2017]")

for df, y in zip(df_all, years):
    fig, ax = plt.subplots(1,1, figsize=(15,5))
    #plt.suptitle("Correlation of World Happiness Index [2015-2019]")
    sns.heatmap(df.corr(), annot=True).set_title(y)

# %%
GDP per capita is highly correlated to healthy life expectancy, score and social support while it has low correlation with genrosity and perception of corruption.

Similarly, correlation of Social support with score, GDP per capita and healthy life expectancy is high.

Freedom to make life choices is correlated only with score, which is obviously not that high.

Generosity and perception of corruption is less correlated.


ВВП на душу населения сильно коррелирует с ожидаемой продолжительностью здоровой жизни, оценкой и социальной поддержкой, в то время как он имеет низкую корреляцию с щедростью и восприятием коррупции.

Точно так же высока корреляция социальной поддержки с баллом, ВВП на душу населения и ожидаемой продолжительностью здоровой жизни.

Свобода делать жизненный выбор коррелирует только с оценкой, которая явно не так высока.
Щедрость и восприятие коррупции менее коррелированы.

# %%
for df, y in zip(df_all,years):
    print(colored(y, attrs=["bold"]))
    a = sns.pairplot(df)
    plt.show()
# Out:
# 2017
# 2016
# 2015

# %%
Greater the score, higher the rank.

Higher ranks have high GDP per capita.

Social support contributes more towards Happiness in countries.

Countries where healthy life expectancy is low are less happy.

Freedom to make choices is better in all countries.

Generosity is common in all countries, low ranking countries are highly generous.

High ranking countries are comparatively clean in case of corruption.

# %%
top_ten_score = df_2017.nlargest(10,"Score")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
plt.suptitle("Correlation of World Happiness Index [2015-2017]")

for df, y in zip(df_all, years):
    fig, ax = plt.subplots(1,1, figsize=(15,5))
    #plt.suptitle("Correlation of World Happiness Index [2015-2019]")
    sns.heatmap(df.corr(), annot=True).set_title(y)
